# %%
import os
import requests

os.makedirs("../data/raw_docs", exist_ok=True)

urls = [
    "https://arxiv.org/pdf/1706.03762.pdf",   # Attention is All You Need
    "https://arxiv.org/pdf/1810.04805.pdf",   # BERT paper
]

for i, url in enumerate(urls):
    response = requests.get(url)
    file_path = f"../data/raw_docs/doc_{i}.pdf"

    with open(file_path, "wb") as f:
        f.write(response.content)

    print(f"Downloaded: {file_path}")
# Out:
# Downloaded: ../data/raw_docs/doc_0.pdf
# Downloaded: ../data/raw_docs/doc_1.pdf

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\vombravalli shankar\OneDrive\rag_ollama_project\notebooks
