# %%
import sys
import os

# 🔥 VERY IMPORTANT
sys.path.append(os.path.abspath(".."))

from src.preprocessing import process_documents

input_dir = r"C:\Users\vombravalli shankar\OneDrive\rag_ollama_project\data\raw_docs"
output_dir = r"C:\Users\vombravalli shankar\OneDrive\rag_ollama_project\data\cleaned"

os.makedirs(output_dir, exist_ok=True)

process_documents(input_dir, output_dir)

print("Cleaning & chunking completed!")
# Out:
# Cleaning & chunking completed!

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from src.preprocessing import process_documents
# Out:
# [nltk_data] Downloading package punkt to C:\Users\vombravalli
# [nltk_data]     shankar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\vombravalli
# [nltk_data]     shankar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\vombravalli
# [nltk_data]     shankar\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
process_documents(input_dir, output_dir)
